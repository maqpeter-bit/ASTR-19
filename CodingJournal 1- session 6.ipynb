# %%
# Importing numpy and astropy at the top here since this will be the first cell ran. 
import numpy as np
from astropy.table import Table



def returnSin(x):
# Inputs: x
# Returns: the sine of x. 
    return np.sin(x)

# %%
def returncos(x):
# Inputs: x
# Returns: the cosine of x. 
    return np.cos(x)

# %%
    #This creates 1000 values between 0 and 2pi. 
    x = np.linspace(0, 2 * np.pi, 1000)
    
    y = np.sin(x)
    z = np.cos(x)

    #Table creation here. 
    table = Table([y, z], names=('sin(x)', 'cosine(x)'))

    # Print table
    print(table)
# Out:
#          sin(x)             cosine(x)
# ----------------------- ------------------
#                     0.0                1.0
#    0.006289433316067751 0.9999802213186832
#    0.012578617838741058 0.9999208860571255
#     0.01886730478446709 0.9998219965624732
#    0.025155245389375847 0.9996835567465339
#      0.0314421909191206 0.9995055720856215
#     0.03772789267871718   0.99928804962034
#     0.04401210202238166 0.9990309979553044
#     0.05029457036336618 0.9987344272588006
#    0.056575049183792345 0.9983983492623831
#                     ...                ...
#   -0.056575049183792726  0.998398349262383
#    -0.05029457036336704 0.9987344272588006
#    -0.04401210202238211 0.9990309979553044
#     -0.0377278926787181   0.99928804962034
#   -0.031442190919121114 0.9995055720856215
#    -0.02515524538937684 0.9996835567465338
#   -0.018867304784467676 0.9998219965624732
#   -0.012578617838742121 0.9999208860571255
#   -0.006289433316068405 0.9999802213186832
# ...

# %%
a = np.cos(x)

# Taking the first 10 values of each of the difference calculations. 
x10 = x[:10]
y10 = y[:10]
a10 = a[:10]

#Creating table here as well since there's now three columns. 
table2 = Table([x10, y10, a10], names=('x', 'sin(x)', 'cos(x)'))

print(table2)
# Out:
#          x                  sin(x)              cos(x)
# -------------------- -------------------- ------------------
#                  0.0                  0.0                1.0
# 0.006289474781961547 0.006289433316067751 0.9999802213186832
# 0.012578949563923095 0.012578617838741058 0.9999208860571255
# 0.018868424345884642  0.01886730478446709 0.9998219965624732
#  0.02515789912784619 0.025155245389375847 0.9996835567465339
#  0.03144737390980774   0.0314421909191206 0.9995055720856215
# 0.037736848691769284  0.03772789267871718   0.99928804962034
#  0.04402632347373083  0.04401210202238166 0.9990309979553044
#  0.05031579825569238  0.05029457036336618 0.9987344272588006
# 0.056605273037653926 0.056575049183792345 0.9983983492623831
