# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit

# %%
# I'm using np.random.normal() for my random number distribution. 
randomNumbers = np.random.normal(loc=0, scale=1, size=1000)
plt.hist(randomNumbers, bins=100, color='green')
plt.xlabel("Value")
plt.ylabel("Frequency")

plt.savefig("CodingJournal2Session5.pdf")

plt.show()
