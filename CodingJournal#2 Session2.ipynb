# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# Creating uncertainties that decrease.
sigma = np.linspace(2, 0.2, 100)

# This is the random scatter / noise for the requirement 
noise = np.random.normal(0, sigma)

# variable for y scatter.
yScatterVariable = y + noise

# Plot with error bars
plt.errorbar(x, yScatterVariable, yerr=sigma, fmt='s', color='green')

# Label axes
plt.xlabel("x")
plt.ylabel("y")

# Save figure
plt.savefig("CodingJournal2Session2plot.pdf")

plt.show()
